# %%
import sys
sys.path.append('../')

from auton_survival.datasets import load_dataset
from auton_survival import DeepCoxMixturesHeterogenousEffects

outcomes, features, interventions = load_dataset(dataset='SYNTHETIC') 

model = DeepCoxMixturesHeterogenousEffects(k=1, g=2, layers=[])

model.fit(features.values, outcomes.time.values, outcomes.event.values, interventions.values)

# %%
from auton_survival.reporting import plot_kaplanmeier

for phi in set(outcomes.Zeta):
	plot_kaplanmeier(outcomes[outcomes.Zeta==phi], interventions[outcomes.Zeta==phi])
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /var/folders/4_/4lmxprs947qfn4f1v92rnp_c0000gn/T/ipykernel_52832/3653944730.py in <module>
#       2
#       3 for phi in set(outcomes.Zeta):
# ----> 4         plot_kaplanmeier(outcomes.iloc[outcomes.Zeta==phi], interventions[outcomes.Zeta==phi])
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     929
#     930             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 931             return self._getitem_axis(maybe_callable, axis=axis)
#     932
#     933     def _is_scalar_access(self, key: tuple):
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1550
#    1551         if com.is_bool_indexer(key):
# -> 1552             self._validate_key(key, axis)
#    1553             return self._getbool_axis(key, axis=axis)
# ...

# %%
outcomes
# Out:
#       event      time  uncensored time treated  uncensored time control    Z  \
# 0      True  3.238760                 3.238760                 0.009182  1.0
# 1      True  3.493217                 3.493217                 6.307030  2.0
# 2      True  2.558462                 1.476810                 2.558462  1.0
# 3      True  5.582874                 5.582874                 4.593198  1.0
# 4      True  6.675284                 3.477266                 6.675284  0.0
# ...     ...       ...                      ...                      ...  ...
# 4995   True  8.066019                 9.611860                 8.066019  1.0
# 4996   True  2.638571                 2.638571                11.376284  0.0
# 4997   True  6.729638                 6.729638                 1.628789  0.0
# 4998   True  0.713366                 3.490827                 0.713366  1.0
# 4999  False  1.637384                 2.764871                 5.568144  0.0
#
#       Zeta
# 0      0.0
# 1      0.0
# ...

# %%
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/4_/4lmxprs947qfn4f1v92rnp_c0000gn/T/ipykernel_52832/1988741118.py in <module>
#       1 model = DeepCoxMixturesHeterogenousEffects(k=1, g=2, layers=[])
#       2
# ----> 3 model.fit(features.values, outcomes.time.values, outcomes.event.values, interventions.values)
#
# ~/Research/auton-survival/examples/../auton_survival/models/cmhe/cmhe_api.py in fit(self, x, t, e, a, vsize, val_data, iters, learning_rate, batch_size, optimizer, random_state)
#     151     model = self._gen_torch_model(inputdim, optimizer)
#     152
# --> 153     model, _ = train_cmhe(model,
#     154                           (x_tr, t_tr, e_tr, a_tr),
#     155                           (x_vl, t_vl, e_vl, a_vl),
#
# ...

# %%
features
# Out:
#             X1        X2        X3        X4        X5        X6        X7  \
# 0     0.148745  1.892484  0.195254  0.860757  0.696523  0.483697  0.339551
# 1     1.139439 -0.943330  0.411054  0.179533  0.428686  0.683057  0.600948
# 2    -0.961237  0.782706 -0.305381  0.583576  0.157478  0.070556  0.034590
# 3     0.466508  0.694348 -0.249651  1.567092  0.850959  0.416178  0.968841
# 4    -0.249002 -0.552091  1.854651 -0.466234  0.860385  0.367184  0.954347
# ...        ...       ...       ...       ...       ...       ...       ...
# 4995  0.377835  2.432757  0.779933 -1.221572  0.505301  0.928557  0.328742
# 4996 -1.018245 -1.553523 -1.543853 -0.951537  0.481382  0.437604  0.743311
# 4997 -1.585228 -0.796665  0.942009  0.201787  0.155891  0.634361  0.544946
# 4998  0.254141  1.583503 -0.411395  1.033718  0.452547  0.369376  0.054975
# 4999 -0.703018  0.358629 -1.904850  1.254300  0.907526  0.391810  0.817667
#
#             X8
# 0     0.374794
# 1     0.070483
# 2     0.776005
# ...
